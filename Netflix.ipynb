# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
movies = pd.read_csv('netflix_titles-2.csv')
movies.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
movies.rename(columns={'release_year':'release yr'}, inplace=True)

# %%
movies.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release yr rating   duration  \
# 0    August 14, 2020        2020  TV-MA  4 Seasons
# 1  December 23, 2016        2016  TV-MA     93 min
# 2  December 20, 2018        2011      R     78 min
# 3  November 16, 2017        2009  PG-13     80 min
# ...

# %%
movies.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director       2389
# cast            718
# country         507
# date_added       10
# release yr        0
# rating            7
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
movies = movies[movies['director'].isnull()==False]

# %%
len(movies)
# Out:
# 5398

# %%
movies.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast           419
# country        205
# date_added       0
# release yr       0
# rating           4
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
movies.head()
# Out:
#   show_id     type  title           director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release yr rating  duration  \
# 1  December 23, 2016        2016  TV-MA    93 min
# 2  December 20, 2018        2011      R    78 min
# 3  November 16, 2017        2009  PG-13    80 min
# 4    January 1, 2020        2008  PG-13   123 min
# ...

# %%
m2 = movies[movies['release yr']>=2015]

# %%
m2.head()
# Out:
#    show_id     type title           director  \
# 1       s2    Movie  7:19  Jorge Michel Grau
# 5       s6  TV Show    46        Serdar Akar
# 6       s7    Movie   122    Yasir Al Yasiri
# 8       s9    Movie   706      Shravan Kumar
# 10     s11    Movie  1922       Zak Hilditch
#
#                                                  cast        country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
#
#            date_added  release yr rating  duration  \
# 1   December 23, 2016        2016  TV-MA    93 min
# 5        July 1, 2017        2016  TV-MA  1 Season
# 6        June 1, 2020        2019  TV-MA    95 min
# 8       April 1, 2019        2019  TV-14   118 min
# ...

# %%
m2['release yr'].unique()
# Out:
# array([2016, 2019, 2017, 2018, 2015, 2020, 2021])

# %%
m2[['release yr', 'duration']].astype('str')
# Out:
#      release yr   duration
# 1          2016     93 min
# 5          2016   1 Season
# 6          2019     95 min
# 8          2019    118 min
# 10         2017    103 min
# 12         2019   1 Season
# 13         2018     89 min
# 14         2019     91 min
# 17         2018    144 min
# 18         2019    124 min
# 20         2018    110 min
# 21         2018    128 min
# 22         2017    117 min
# 23         2017    100 min
# 25         2015     84 min
# 27         2020     99 min
# 28         2019     95 min
# 30         2020     90 min
# 31         2018    102 min
# 32         2020    104 min
# 33         2017     99 min
# 34         2018    105 min
# 35         2016     56 min
# 37         2016    119 min
# 39         2019     81 min
# 40         2015     97 min
# 41         2017    106 min
# 43         2020    107 min
# 47         2017    105 min
# 48         2017     87 min
# 54         2016    109 min
# 56         2016     75 min
# 57         2020    101 min
# ...

# %%
m2.head()
# Out:
#    show_id     type title           director  \
# 1       s2    Movie  7:19  Jorge Michel Grau
# 5       s6  TV Show    46        Serdar Akar
# 6       s7    Movie   122    Yasir Al Yasiri
# 8       s9    Movie   706      Shravan Kumar
# 10     s11    Movie  1922       Zak Hilditch
#
#                                                  cast        country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 6   Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
#
#            date_added  release yr rating  duration  \
# 1   December 23, 2016        2016  TV-MA    93 min
# 5        July 1, 2017        2016  TV-MA  1 Season
# 6        June 1, 2020        2019  TV-MA    95 min
# 8       April 1, 2019        2019  TV-14   118 min
# ...

# %%
m2['Cast or not'] = np.where(m2['cast'].isnull(), 'NOT', 'CAST')
# Out:
# /Users/karishmavelagaleti/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3530 entries, 1 to 7786
# Data columns (total 13 columns):
# show_id        3530 non-null object
# type           3530 non-null object
# title          3530 non-null object
# director       3530 non-null object
# cast           3174 non-null object
# country        3361 non-null object
# date_added     3530 non-null object
# release yr     3530 non-null int64
# rating         3527 non-null object
# duration       3530 non-null object
# listed_in      3530 non-null object
# description    3530 non-null object
# Cast or not    3530 non-null object
# dtypes: int64(1), object(12)
# memory usage: 546.1+ KB

# %%
m2.sort_values(by='release yr', ascending=False, inplace=True)
# Out:
# /Users/karishmavelagaleti/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
m2.head()
# Out:
#      show_id   type                                              title  \
# 1514   s1515  Movie            Crack: Cocaine, Corruption & Conspiracy
# 1355   s1356  Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5103   s5104  Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 7220   s7221  Movie                      Tribhanga - Tedhi Medhi Crazy
# 4710   s4711  Movie                                   Outside the Wire
#
#                              director  \
# 1514                   Stanley Nelson
# 1355                       Chris Rock
# 5103  Alejandro Ruax, Ramiro Martínez
# 7220                   Renuka Shahane
# 4710                  Mikael Håfström
#
#                                                    cast        country  \
# 1514                                                NaN  United States
# 1355                                         Chris Rock            NaN
# 5103  Juan Sebastián Gutiérrez, Pablo Cano, Pablo Me...            NaN
# ...

# %% [markdown]
# ### Exploring data

# %%
len(movies)
# Out:
# 7787

# %%
movies['release_year'].describe()
# Out:
# count    7787.000000
# mean     2013.932580
# std         8.757395
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2018.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
#sns.distplot(movies['release_year'])

# %%
#### Since distplot is taking a lot of time I am trying to move this to an array and use hist()

# %%
release_year = movies['release_year'].values

# %%
type(release_year)
# Out:
# numpy.ndarray

# %%
plt.hist(release_year)
